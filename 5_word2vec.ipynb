# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
data = (zipfile.ZipFile(filename).read(zipfile.ZipFile(filename).namelist()[0]).split())

# %%
data[:10]
# Out:
# [b'anarchism',
#  b'originated',
#  b'as',
#  b'a',
#  b'term',
#  b'of',
#  b'abuse',
#  b'first',
#  b'used',
#  b'against']

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    # select most common 49999 words, left one for unknown (all other words)
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3083, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'originated', 'term', 'as', 'originated', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.976251
# Nearest to called: contractual, diab, bonner, lenz, articulation, relieved, glenn, tombstone,
# Nearest to but: formulated, pegasus, fists, urquhart, stereotyped, handshake, remake, kernels,
# Nearest to most: de, feng, vyasa, carlo, bukhari, fugitives, eglise, donnelly,
# Nearest to his: johannine, claymore, prot, soul, transplanted, calendar, combinations, botvinnik,
# Nearest to i: manorial, riverside, romanization, inconvenience, bst, pebble, campuses, assignment,
# Nearest to not: ponder, vasoconstriction, furlong, zoos, flaccus, consults, arena, irl,
# Nearest to th: placed, rope, occasionally, coup, gerais, investigate, humour, origen,
# Nearest to people: meier, refrained, commonality, canceled, monastics, nationalist, rod, wildlife,
# Nearest to will: emit, honoured, gaians, orbiter, insertion, mumbai, configurations, sour,
# Nearest to no: rudi, lettuce, prepositional, ule, furthering, cartoonists, hawkins, glace,
# Nearest to which: repealed, octaves, clowning, defiant, treviso, melvin, formulated, lackey,
# Nearest to states: chromatids, kazimierz, dispensing, secretaries, philby, licks, graphing, misunderstandings,
# Nearest to an: inked, basements, starfighter, calicut, bred, futility, ornaments, boasts,
# Nearest to if: rotation, santer, gilt, engel, appropriations, ub, danish, masons,
# Nearest to between: andropov, auditing, absurdum, valve, knight, contrabass, krause, appropriating,
# Nearest to often: bombarded, substratum, corel, penetrative, overvalued, instalments, cane, antennae,
# Average loss at step 2000: 4.375270
# Average loss at step 4000: 3.867397
# Average loss at step 6000: 3.787668
# Average loss at step 8000: 3.691967
# Average loss at step 10000: 3.612638
# Nearest to called: lenz, seam, braxton, blisters, glenn, excursions, bonner, contractual,
# Nearest to but: fists, which, and, reestablished, powerpc, pac, is, chassis,
# Nearest to most: feng, idea, eglise, fugitives, renegades, patenting, epistles, donnelly,
# Nearest to his: their, her, the, s, its, infidels, prot, this,
# Nearest to i: romanization, milliseconds, blooms, gimp, manorial, integrated, shang, bechtel,
# Nearest to not: it, they, to, also, hodder, still, affirmation, germain,
# Nearest to th: rope, seduction, rd, occasionally, surveyed, coup, placed, investigate,
# Nearest to people: meier, them, commonality, monastics, those, etna, saucers, vortigern,
# Nearest to will: would, emit, circulate, hounds, cypress, gottfried, vanir, orbiter,
# Nearest to no: prepositional, nurtured, it, pickguard, kline, macworld, hawkins, never,
# Nearest to which: it, this, but, that, there, watchmen, who, still,
# Nearest to states: graphing, kazimierz, dispensing, hypoxia, cos, kingdom, played, coleco,
# Nearest to an: inked, basements, boasts, hood, theresa, the, anu, puzzled,
# Nearest to if: that, santer, mei, files, just, geek, inks, spacecraft,
# Nearest to between: higham, andropov, absurdum, eventual, krause, knight, xxvii, digraph,
# Nearest to often: halt, cryptologia, also, mambo, prescriptions, bombarded, overvalued, structurally,
# Average loss at step 12000: 3.603402
# Average loss at step 14000: 3.568144
# Average loss at step 16000: 3.405077
# Average loss at step 18000: 3.457474
# Average loss at step 20000: 3.536618
# Nearest to called: seam, braxton, overthrowing, lenz, soga, musicality, andromeda, glenn,
# Nearest to but: however, which, and, if, was, when, that, varanus,
# Nearest to most: some, feng, many, more, among, dovich, stickball, idea,
# Nearest to his: their, her, its, prot, many, extrinsic, investigations, the,
# Nearest to i: ii, t, milliseconds, integrated, you, they, iv, hellespont,
# Nearest to not: it, they, usually, also, still, to, we, nor,
# Nearest to th: rd, seduction, rope, nd, m, occasionally, afp, placed,
# Nearest to people: those, meier, commonality, vortigern, them, episcopate, monastics, material,
# Nearest to will: would, can, could, may, should, circulate, must, to,
# Nearest to no: prepositional, nurtured, pickguard, macworld, a, snegur, any, waxing,
# Nearest to which: that, this, it, there, who, but, also, and,
# Nearest to states: kingdom, graphing, cos, hypoxia, kazimierz, dispensing, played, haran,
# Nearest to an: the, basements, inked, anu, this, kazakhstan, akademia, mistakenly,
# Nearest to if: but, that, just, santer, mei, though, although, backfired,
# Nearest to between: from, through, under, with, andropov, into, higham, poland,
# Nearest to often: also, commonly, widely, usually, halt, who, frequently, cryptologia,
# Average loss at step 22000: 3.503609
# Average loss at step 24000: 3.484919
# Average loss at step 26000: 3.483968
# Average loss at step 28000: 3.477228
# Average loss at step 30000: 3.502723
# Nearest to called: seam, braxton, overthrowing, used, structuring, soga, andromeda, lenz,
# Nearest to but: however, if, and, which, although, when, though, is,
# Nearest to most: many, more, some, feng, coimbra, donnelly, among, fugitives,
# Nearest to his: their, her, its, prot, the, my, s, keg,
# Nearest to i: ii, t, you, we, iv, lodgings, derek, milliseconds,
# Nearest to not: they, nor, still, usually, to, we, always, generally,
# Nearest to th: rd, nd, bc, seduction, isbn, priceless, six, surveyed,
# Nearest to people: those, vortigern, commonality, meier, them, monastics, saucers, children,
# Nearest to will: would, can, could, may, should, cannot, must, circulate,
# Nearest to no: any, prepositional, pickguard, ewen, whyte, a, macworld, still,
# Nearest to which: this, that, it, but, there, these, also, who,
# Nearest to states: kingdom, graphing, haran, kazimierz, dispensing, hypoxia, scanned, coleco,
# Nearest to an: inked, disarmament, anu, basements, mistakenly, shaken, americans, limericks,
# Nearest to if: when, but, that, although, though, where, cul, let,
# Nearest to between: with, from, under, through, protects, lagrangian, over, in,
# Nearest to often: usually, commonly, widely, frequently, also, generally, sometimes, there,
# Average loss at step 32000: 3.506989
# Average loss at step 34000: 3.496272
# Average loss at step 36000: 3.449392
# Average loss at step 38000: 3.298415
# Average loss at step 40000: 3.428479
# Nearest to called: braxton, structuring, seam, overthrowing, soga, used, shouted, andromeda,
# Nearest to but: however, though, and, although, compatible, it, if, tove,
# Nearest to most: more, some, many, coimbra, among, feng, flattening, humphreys,
# Nearest to his: their, her, its, the, my, prot, s, your,
# Nearest to i: ii, t, you, we, he, they, lodgings, iv,
# Nearest to not: usually, still, they, generally, cardoso, considered, it, always,
# Nearest to th: rd, nd, bc, seduction, nguyen, priceless, isbn, necessitate,
# Nearest to people: those, them, vortigern, lyman, dioceses, monastics, children, others,
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to no: any, prepositional, macworld, nurtured, whyte, tip, pickguard, ewen,
# Nearest to which: that, this, also, who, it, there, what, often,
# Nearest to states: kingdom, graphing, countries, scanned, state, greatness, kazimierz, autobiographies,
# Nearest to an: disarmament, basements, inked, limericks, mistakenly, anu, akademia, sensory,
# Nearest to if: when, where, though, that, is, for, pay, but,
# Nearest to between: from, with, in, over, couscous, through, protects, into,
# Nearest to often: usually, widely, commonly, frequently, sometimes, also, generally, who,
# Average loss at step 42000: 3.433593
# Average loss at step 44000: 3.457804
# Average loss at step 46000: 3.448456
# Average loss at step 48000: 3.356029
# Average loss at step 50000: 3.383077
# Nearest to called: braxton, structuring, seam, com, used, galatea, ero, asked,
# Nearest to but: however, though, and, although, when, while, during, remains,
# Nearest to most: more, many, some, less, among, coimbra, particularly, flattening,
# Nearest to his: their, her, its, my, the, your, prot, him,
# Nearest to i: you, ii, t, we, g, he, lodgings, iii,
# Nearest to not: usually, generally, still, we, considered, they, never, always,
# Nearest to th: rd, bc, nd, nguyen, seduction, five, isbn, girlfriend,
# Nearest to people: children, men, those, bcp, jews, years, bolivar, them,
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to no: any, macworld, a, pickguard, nurtured, whyte, reins, snegur,
# Nearest to which: that, this, also, who, these, what, however, still,
# Nearest to states: kingdom, graphing, countries, scanned, registration, autobiographies, quicksort, state,
# Nearest to an: basements, disarmament, sensory, lodging, mistakenly, linnaean, akademia, kkk,
# Nearest to if: when, where, though, although, while, could, subsided, is,
# Nearest to between: with, from, through, protects, couscous, over, into, around,
# Nearest to often: usually, commonly, sometimes, generally, widely, frequently, also, now,
# Average loss at step 52000: 3.435717
# Average loss at step 54000: 3.427631
# Average loss at step 56000: 3.439662
# Average loss at step 58000: 3.395723
# Average loss at step 60000: 3.398181
# Nearest to called: used, structuring, braxton, com, signatures, shor, see, scaffold,
# Nearest to but: however, and, although, though, which, bruises, when, see,
# Nearest to most: many, more, some, among, coimbra, particularly, less, feng,
# Nearest to his: her, their, its, my, the, your, energies, sacher,
# Nearest to i: you, we, t, ii, g, they, imperfections, reinforcements,
# Nearest to not: usually, still, considered, cardoso, malt, you, now, generally,
# Nearest to th: rd, bc, isbn, nd, nguyen, seduction, girlfriend, four,
# Nearest to people: those, men, others, children, scholars, jews, lyman, bcp,
# Nearest to will: would, could, can, may, must, cannot, should, might,
# Nearest to no: any, pickguard, nurtured, macworld, prepositional, whyte, amazigh, hallelujah,
# Nearest to which: that, this, what, who, these, it, but, however,
# Nearest to states: kingdom, countries, nations, graphing, state, scanned, people, registration,
# Nearest to an: disarmament, inked, basements, sensory, rosslyn, kkk, this, grimoires,
# Nearest to if: when, where, though, since, although, before, then, could,
# Nearest to between: with, in, from, over, among, through, couscous, monetarist,
# Nearest to often: usually, sometimes, commonly, frequently, widely, generally, also, now,
# Average loss at step 62000: 3.234984
# Average loss at step 64000: 3.256883
# Average loss at step 66000: 3.405575
# Average loss at step 68000: 3.395055
# Average loss at step 70000: 3.357233
# Nearest to called: named, referred, braxton, used, soga, see, structuring, theodoret,
# Nearest to but: however, although, though, which, and, that, bruises, while,
# Nearest to most: more, many, some, less, particularly, several, microcomputer, among,
# Nearest to his: her, their, its, my, your, sacher, our, the,
# Nearest to i: we, you, ii, t, g, derek, stefano, iv,
# Nearest to not: still, usually, generally, malt, never, now, nor, always,
# Nearest to th: bc, rd, nd, nguyen, seduction, priceless, isbn, girlfriend,
# Nearest to people: women, men, those, children, haran, jews, bcp, students,
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to no: any, macworld, nurtured, whyte, pickguard, amazigh, tuscan, banchan,
# Nearest to which: that, this, but, what, also, these, who, bubblegum,
# Nearest to states: kingdom, nations, countries, state, scanned, graphing, groups, babylonian,
# Nearest to an: disarmament, inked, akademia, sensory, mistakenly, basements, shaken, laszlo,
# Nearest to if: when, though, where, although, since, before, while, could,
# Nearest to between: with, from, through, among, within, into, around, in,
# Nearest to often: sometimes, usually, frequently, commonly, generally, now, widely, typically,
# Average loss at step 72000: 3.378750
# Average loss at step 74000: 3.348781
# Average loss at step 76000: 3.320692
# Average loss at step 78000: 3.355535
# Average loss at step 80000: 3.374609
# Nearest to called: named, known, used, referred, considered, soga, galatea, structuring,
# Nearest to but: however, although, while, and, though, which, remains, or,
# Nearest to most: many, more, some, less, particularly, among, microcomputer, especially,
# Nearest to his: her, their, its, my, your, our, personal, the,
# Nearest to i: ii, we, t, you, g, they, iii, iv,
# Nearest to not: still, usually, generally, malt, we, nor, they, never,
# Nearest to th: bc, rd, nd, nguyen, isbn, km, girlfriend, three,
# Nearest to people: children, men, women, individuals, bcp, jews, students, haran,
# Nearest to will: would, could, can, may, must, should, cannot, might,
# Nearest to no: macworld, any, nurtured, reins, embroiled, banchan, tuscan, amazigh,
# Nearest to which: that, this, also, who, what, often, but, citt,
# Nearest to states: kingdom, nations, countries, scanned, state, babylonian, graphing, us,
# Nearest to an: disarmament, mistakenly, rosslyn, cour, inked, kkk, sensory, puzzled,
# Nearest to if: when, though, where, since, although, whether, then, before,
# Nearest to between: with, within, through, among, from, in, around, including,
# Nearest to often: sometimes, usually, frequently, commonly, generally, typically, widely, now,
# Average loss at step 82000: 3.411781
# Average loss at step 84000: 3.409300
# Average loss at step 86000: 3.390989
# Average loss at step 88000: 3.351289
# Average loss at step 90000: 3.366345
# Nearest to called: named, referred, used, considered, known, galatea, learnt, braxton,
# Nearest to but: however, and, although, though, while, which, bruises, grossly,
# Nearest to most: many, more, some, less, particularly, among, strongest, several,
# Nearest to his: her, their, its, my, your, our, the, whiteman,
# Nearest to i: we, you, t, ii, g, iii, iv, derek,
# Nearest to not: still, nor, generally, realization, never, we, somewhat, malt,
# Nearest to th: bc, rd, nguyen, nd, seven, nine, nineteenth, km,
# Nearest to people: children, women, men, jews, students, players, individuals, members,
# Nearest to will: would, could, can, may, must, should, cannot, might,
# Nearest to no: any, little, whyte, collaborators, nurtured, banchan, macworld, never,
# Nearest to which: that, this, also, what, usually, who, but, chemnitz,
# Nearest to states: kingdom, nations, scanned, countries, us, state, babylonian, exclamation,
# Nearest to an: ozarks, disarmament, inked, mistakenly, encyclopedias, laszlo, basements, another,
# Nearest to if: when, where, though, since, before, then, becomes, although,
# Nearest to between: with, in, within, among, through, from, against, into,
# Nearest to often: sometimes, usually, commonly, frequently, generally, also, now, widely,
# Average loss at step 92000: 3.400920
# Average loss at step 94000: 3.253497
# Average loss at step 96000: 3.361474
# Average loss at step 98000: 3.243679
# Average loss at step 100000: 3.357908
# Nearest to called: named, referred, com, galatea, used, polluting, gambier, geats,
# Nearest to but: however, although, though, and, while, which, when, grossly,
# Nearest to most: more, less, particularly, many, among, throughout, especially, some,
# Nearest to his: her, their, its, my, your, our, the, personal,
# Nearest to i: we, you, ii, t, v, they, g, derek,
# Nearest to not: nor, still, never, sympathized, generally, you, they, considered,
# Nearest to th: bc, rd, nguyen, nd, nineteenth, second, fourth, third,
# Nearest to people: children, women, men, jews, players, students, individuals, haran,
# Nearest to will: would, could, can, must, may, should, cannot, might,
# Nearest to no: any, whyte, macworld, embroiled, nurtured, only, collaborators, maradona,
# Nearest to which: that, this, what, usually, citt, actually, often, these,
# Nearest to states: kingdom, nations, countries, us, scanned, exclamation, state, babylonian,
# Nearest to an: inked, sensory, another, mistakenly, disarmament, highbury, basements, chagrin,
# Nearest to if: when, where, though, then, before, since, although, chromaticity,
# Nearest to between: with, through, within, among, protects, over, lagrangian, around,
# Nearest to often: sometimes, usually, generally, commonly, frequently, widely, typically, rarely,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
